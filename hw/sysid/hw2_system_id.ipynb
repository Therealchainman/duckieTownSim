# %%
import sys
sys.path.append('../')

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import json

# %% [markdown]
# ## Data Collection

# %% [markdown]
# Before you can begin here you're going to have to collect some data driving around.  Run the simulator in sysID_data mode to do this (command below).  Just drive around, accelerating and braking as you normally would.  After driving around for a minute or two press 's' to save your data (You should receive a confirmation).
#
# python simulator.py --mode sysID_data
#
# As a reminder controls in the simulator are as follows:
#
# 1.Press 'f' to get started (this puts you in forward gear)
#
# 2.Arrow keys to control.
#
# 3.Control C to exit simulator
#
# Don't forget to save your data before exiting!
#
# If your interested in further details during this assignment or next weeks, please reference the fully commented simulator.py file.  This file handles the simulator and it's interactions with user input and the Car_Interface.

# %% [markdown]
# ## Data Preprocessing

# %%
'''
Load data points from json file
'''
from google.colab import files
uploaded = files.upload()

file_name = "simple_data_points.json"

data_points = json.loads(uploaded[file_name].decode("utf-8"))
'''
These lists will all be of length equal to the
number of available data points. The first list
will store the time each data point was logged,
the second the 3-dimensional inputs discussed below,
and the third the acceleration values.
'''
all_times = []
all_inps = []
all_outs = []

'''
These lists will store the same values as the ones
above, except they will omit a specific set of data
points that exhibit non linear behavior.  More on this
below.
'''
filt_times = []
filt_inps = []
filt_outs = []


'''
t: 0 to (N - 1)
ped: 'accelerator', 'brake', or None
amt: 0 to 1
vel: 0 to 1
acc: 0 to 1
'''
for t, (ped, amt, vel, acc) in enumerate(data_points):
    
    '''
    We are trying to fit a linear model for acceleration
    that uses three values for inputs: the accelerator depression
    amount, the brake depression amount, and the velocity.  Further
    we will fit an intercept as well (bias).
    
    In order to do this we format our data as input output pairs where
    input is a list consisting of the the appropriate linear dependencies
    and the output is the corresponding acceleration.
    
    Your code should result in 'inp' referencing a list of length 3 that 
    contains: [accelerator amount, brake amount, velocity]
    '''
    if ped == "accelerator":
      inp = [amt, 0, vel]]
    elif ped == "brake":
      inp = [0, amt, vel]
    else: 
      inp = [0, 0, vel]
    all_inps.append(inp)
    all_outs.append(acc)
    all_times.append(t)


    '''
    You may notice that your linear model struggles with a specific scenario.
    This scenario results in your linear model being a poor fit for the general trend.
    Specifically there is a specific circumstance in which acceleration behaves nonlinearly,
    and it hurts the model to accomodate this.
    Here we will remedy this issue by filtering out the nonlinear scenario and fit a better
    linear model to the true linear data.
    HINT: Do you ever move backwards when in forward gear? When might the model think you should?
    '''
    if (vel >= 0):
        filt_inps.append(inp)
        filt_outs.append(acc)
        filt_times.append(t)
          

plt.title("Collected Data")
plt.xlabel("Time")
plt.ylabel("Acceleration")
plt.scatter(all_times, all_outs, color = 'b')
plt.show()

plt.title("Collected Data")
plt.xlabel("Time")
plt.ylabel("Velocity")
plt.scatter(all_times, [vel for (_, _, vel) in all_inps], color = 'b')
plt.show()
# Out:
#      <input type="file" id="files-5c84fae3-14bc-4db2-a7e5-8b7c3a64d790" name="files[]" multiple disabled />
#      <output id="result-5c84fae3-14bc-4db2-a7e5-8b7c3a64d790">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving simple_data_points.json to simple_data_points (17).json
# [[None, 0, 0.0029773879872237057, 0.010089377223894823], [None, 0, 0.0059115055320849595, 0.009801816483853655], [None, 0, -0.0038900187487788925, 0.009824486328127345], [None, 0, 0.002042197010772798, 0.00981822628832853], [None, 0, 0.0011909956678240626, 0.009800933208904654], [None, 0, 0.009599612283699632, 0.009612813787018911], [None, 0, 0.00384812885443768, 0.00959448099656729], [None, 0, 0.007699365210937169, 0.009471140844672188], [None, 0, 0.0030255336568745968, 0.009372038371610002], [None, 0, 0.003753179442461698, 0.009358268595706817], [None, 0, 0.005127859556693195, 0.009208049205039067], [None, 0, 0.01626832862990249, 0.009276882576748299], [None, 0, 0.006602176981857422, 0.009233330129389051], [None, 0, 0.003077033183075932, 0.009054765557490737], [None, 0, 0.015066517926110697, 0.008998667547386993], [None, 0, 0.00965551486753237, 0.009013325718257584], [None, 0, 0.005481845224722464, 0.008918772806308572], [None, 0, 0.019820565154849264, 0.008795729091094304], [None, 0, 0.019932901244797317, 0.008778861264003032], [None, 0, 0.013789042342145199, 0.00861288452666429], [None, 0, 0.018688428135799347, 0.008631920869440349], [None, 0, 0.0076526745572306635, 0.008544877596412223], [None, 0, 0.02355494306360529, 0.008511588949536481], [None, 0, 0.015823181053026696, 0.008392946766155122], [None, 0, 0.014304431436255328, 0.008331687903043164], [None, 0, 0.023177488312462163, 0.008342969139438336], [None, 0, 0.01934460130247628, 0.008293581702216075], [None, 0, 0.018833656086939127, 0.00817222145680501], [None, 0, 0.030574327162803824, 0.008143162904365918], [None, 0, 0.014000381421231969, 0.008031304476641535], [None, 0, 0.014599056728321354, 0.008033694081742877], [None, 0, 0.020257314807543874, 0.007977450893238784], [None, 0, 0.023202752526287874, 0.007919255170719097], [None, 0, 0.01921691436774654, 0.007863558378115143], [None, 0, 0.018356165116944555, 0.007839380479255682], [None, 0, 0.018658721453647702, 0.007631553085133123], [None, 0, 0.02513070384609081, 0.007632154705350131], [None, 0, 0.02396843939380918, 0.007718620410513887], [None, 0, 0.026884390771508726, 0.00758428201202457], [None, 0, 0.01876677000799, 0.007474123566090326], [None, 0, 0.034810576558705564, 0.007381347743935436], [None, 0, 0.02490687218195156, 0.007395618475440277], [None, 0, 0.026896243347934286, 0.0073053454115540335], [None, 0, 0.021505946047286468, 0.007324128957349087], [None, 0, 0.018168195779852892, 0.007299339396549613], [None, 0, 0.02299907606531332, 0.007116994558439334], [None, 0, 0.024077848807650664, 0.007111960560827606], [None, 0, 0.03137086392811204, 0.007081658819326932], [None, 0, 0.029417208150368374, 0.007033118230389625], [None, 0, 0.023853116523370865, 0.006955381844762431], [None, 0, 0.015531722638409965, 0.006940297303966128], [None, 0, 0.025203008795886616, 0.006874692287784804], [None, 0, 0.026326642416076608, 0.006765798667172151], [None, 0, 0.03371860406885885, 0.00671438475414488], [None, 0, 0.036711231480331036, 0.006727283480199864], [None, 0, 0.03076927846374006, 0.006602177507221129], [None, 0, 0.042245255901259056, 0.0065341708681076775], [None, 0, 0.03200074372273324, 0.006534439919233446], [None, 0, 0.036877922845232704, 0.0065806704744443886], [None, 0, 0.03859510480024555, 0.006458337168062721], [None, 0, 0.029950540070421, 0.006514027506255467], [None, 0, 0.032394328513204444, 0.006430687994910006], [None, 0, 0.03674330902071416, 0.006339871169375337], [None, 0, 0.02735983257387214, 0.006187135148842391], [None, 0, 0.03267412168985567, 0.006142301930334682], [None, 0, 0.030794611079361326, 0.00621305868711545], [None, 0, 0.029343371967826982, 0.006161452384512262], [None, 0, 0.03770391012502068, 0.006106408094861798], [None, 0, 0.0325135686711358, 0.006041535252880997], [None, 0, 0.03312347206151616, 0.006052014030050621], [None, 0, 0.032572192147448595, 0.006058477331631518], [None, 0, 0.04514010528252288, 0.005910446948638757], [None, 0, 0.0385016533902921, 0.005883676952801044], [None, 0, 0.0 ...
# the velocity is 0.5546399843889811, and the acceleration is -0.21987418799511219
# the velocity is 0.5322196921619251, and the acceleration is -0.26175238500621795
# the velocity is 0.5144753557422307, and the acceleration is -0.2897347424677207
# the velocity is 0.501161416313467, and the acceleration is -0.1753670916345436
# the velocity is 0.4868674777014755, and the acceleration is -0.2601651408977536
# the velocity is 0.4708475533731236, and the acceleration is -0.07268522151045911
# the velocity is 0.45537013337943183, and the acceleration is -0.13130709126371706
# the velocity is 0.4511929621107694, and the acceleration is -0.05926665592350649
# the velocity is 0.45299080888645893, and the acceleration is -0.18992052097888795
# the velocity is 0.44248711178035344, and the acceleration is -0.18851787405653647
# the velocity is 0.4291621173428005, and the acceleration is -0.2656022806061786
# the velocity is 0.40439991397489594, and the acceleration is -0.24716596455014142
# the velocity is 0.387760400582798, and the acceleration is -0.12794477210298044
# the velocity is 0.39159607470931085, and the acceleration is -0.27015321300261347
# the velocity is 0.3700947338241213, and the acceleration is -0.05423818672228497
# the velocity is 0.37025023794101486, and the acceleration is -0.2235954211254592
# the velocity is 0.3448345875310363, and the acceleration is -0.04998266241575297
# the velocity is 0.3386014264034811, and the acceleration is -0.06004178961354077
# the velocity is 0.3360429074169102, and the acceleration is -0.23210658614559274
# the velocity is 0.3232163831815985, and the acceleration is -0.09833965104706019
# the velocity is 0.31780863010607474, and the acceleration is -0.23602583780278513
# the velocity is 0.29382525965246625, and the acceleration is -0.2234914405000952
# the velocity is 0.29277966563311975, and the acceleration is -0.21087803210339148
# the velocity is 0.27985650724162675, and the acceleration is -0.13505706365108586
# the velocity is 0.267949727831683, and the acceleration is -0.10874434107165626
# the velocity is 0.25794850862819807, and the acceleration is -0.25424235630685565
# the velocity is 0.24635443411262467, and the acceleration is -0.05204055830245047
# the velocity is 0.22858446157165113, and the acceleration is -0.2387235568248436
# the velocity is 0.21683581243128924, and the acceleration is -0.26091587438743163
# the velocity is 0.2081520148732709, and the acceleration is -0.23027758843880614
# the velocity is 0.19008259628581842, and the acceleration is -0.09576141023371375
# the velocity is 0.1834827177385152, and the acceleration is -0.06565002029310917
# the velocity is 0.1712134750543928, and the acceleration is -0.033243983002102295
# the velocity is 0.1682053764048403, and the acceleration is -0.1616764311155409
# the velocity is 0.1691257597843415, and the acceleration is -0.13934079875259134
# the velocity is 0.15329353945940405, and the acceleration is -0.056208703480737504
# the velocity is 0.14266104579342884, and the acceleration is -0.01674628263552207
# the velocity is 0.1502240836231231, and the acceleration is -0.049569293338194535
# the velocity is 0.14589931642468906, and the acceleration is -0.08562250296964936
# the velocity is 0.13731946397172748, and the acceleration is -0.22628658603544446
# the velocity is 0.12501849379352, and the acceleration is -0.11636148511332636
# the velocity is 0.11750492362771503, and the acceleration is -0.12462793528088997
# the velocity is 0.10817235180083741, and the acceleration is -0.17523502263172674
# the velocity is 0.10162017330133513, and the acceleration is -0.19949931144490207
# the velocity is 0.0801889537242584, and the acceleration is -0.1322809192217818
# the velocity is 0.0825241257816084, and the acceleration is -0.1796644288433271
# the velocity is 0.06040270958834904, and the acceleration is -0.20674482326334434
# the velocity is 0.051473217699683355, and the acceleration is -0.027894489293191115
# the velocity is 0.052525288706456855, and the acceleration is -0.13288224552838648
# the velocity is 0.03634656062513105, and the acceleration is -0.2296852694693953
# the velocity is 0.027296058944166285, and the acceleration is -0.07167666593333744
# the velocity is 0.0175923953545754, and the acceleration is -0.12255153249288765
# the velocity is 0.011511318427665283, and the acceleration is -0.013781447850715339
# the velocity is 0.006054165470331522, and the acceleration is -0.21404810434565147
# the velocity is 0.000772595608015368, and the acceleration is 6.775252007667246e-06
# the velocity is 0.5189158486181954, and the acceleration is -0.12018199071252095
# the velocity is 0.4976677949654813, and the acceleration is -0.15147926491782082
# the velocity is 0.4950258197791978, and the acceleration is -0.1695866179877223
# the velocity is 0.485101755836407, and the acceleration is -0.1764956480902042
# the velocity is 0.46718681586254224, and the acceleration is -0.04584324542212983
# the velocity is 0.46834894216748996, and the acceleration is -0.26103487133848324
# the velocity is 0.4543156372291591, and the acceleration is -0.15483812087148452
# the velocity is 0.4371566359485542, and the acceleration is -0.18956494283909994
# the velocity is 0.428067911487095, and the acceleration is -0.1296723967090579
# the velocity is 0.42013955780902557, and the acceleration is -0.23243144176572425
# the velocity is 0.40332515663179586, and the acceleration is -0.21920017226253863
# the velocity is 0.3811714023293679, and the acceleration is -0.1072425593719115
# the velocity is 0.3847835352801346, and the acceleration is -0.09539995451211955
# the velocity is 0.370702164482891, and the acceleration is -0.13502365821549608
# the velocity is 0.3730471154808202, and the acceleration is -0.2752880878389444
# the velocity is 0.3444319036250985, and the acceleration is -0.2676821020028887
# the velocity is 0.3335735762447224, and the acceleration is -0.23079755975619132
# the velocity is 0.32131563875633185, and the acceleration is -0.229870379043826
# the velocity is 0.2980476800167965, and the acceleration is -0.10674515196378383
# the velocity is 0.2977213403223772, and the acceleration is -0.17634549137497812
# the velocity is 0.2775823773449253, and the acceleration is -0.22902893689248446
# the velocity is 0.26536975043921945, and the acceleration is -0.20951632354081542
# the velocity is 0.2573058345496289, and the acceleration is -0.05297620661902022
# the velocity is 0.2504306622557555, and the acceleration is -0.17687222765023594
# the velocity is 0.24097169363297352, and the acceleration is -0.19610613186090387
# the velocity is 0.22708423574071168, and the acceleration is -0.11062971054911663
# the velocity is 0.21433575381849748, and the acceleration is -0.06669540520566487
# the velocity is 0.2119234978417035, and the acceleration is -0.07452213541530646
# the velocity is 0.2101065515761629, and the acceleration is -0.19592721333947885
# the velocity is 0.19634233050944647, and the acceleration is -0.18228588328003595
# the velocity is 0.18239359930632348, and the acceleration is -0.1320175482252804
# the velocity is 0.1737254344712625, and the acceleration is -0.12921151502322964
# the velocity is 0.16390179592556267, and the acceleration is -0.14206517851633116
# the velocity is 0.1583105510577968, and the acceleration is -0.05392962650151713
# the velocity is 0.1416703797846531, and the acceleration is -0.029277843527562714
# the velocity is 0.15571384265938792, and the acceleration is -0.0939048831312558
# the velocity is 0.142932345805945, and the acceleration is -0.22819012442299583
# the velocity is 0.12406254284593336, and the acceleration is -0.11769524477206232
# the velocity is 0.1200445808646468, and the acceleration is -0.04026912670632796
# the velocity is 0.10897382374928793, and the acceleration is -0.11702886738137534
# the velocity is 0.10282694533529055, and the acceleration is -0.008788884986286983
# the velocity is 0.10798136625607457, and the acceleration is -0.198745057706189
# the velocity is 0.09496822698091043, and the acceleration is -0.23716300088058254
# the velocity is 0.0822228783722089, and the acceleration is -0.04545413605264981
# the velocity is 0.07971906395634933, and the acceleration is -0.17857046443602756
# the velocity is 0.06717120836643896, and the acceleration is -0.1669538439443721
# the velocity is 0.05457612639894294, and the acceleration is -0.07636263477948114
# the velocity is 0.04972458256125081, and the acceleration is -0.006336753515541997
# the velocity is 0.04986672027408828, and the acceleration is -0.21338744849810518
# the velocity is 0.026939882909009838, and the acceleration is -0.22988481622736703
# the velocity is 0.016462212685980252, and the acceleration is -0.09882952528812726
# the velocity is 0.0120905415698879, and the acceleration is -0.0672858270318435
# the velocity is 0.005190690508572906, and the acceleration is -0.08425012018945681
# the velocity is 0.006447805278610434, and the acceleration is -2.4011250945421426e-05
# the velocity is 0.009116359421842803, and the acceleration is -6.855625118406161e-05
# the velocity is 0.5191714125950108, and the acceleration is -0.27083222163393916
# the velocity is 0.5154734208457781, and the acceleration is -0.11018096823602527
# the velocity is 0.5031561557287803, and the acceleration is -0.13540700188975105
# the velocity is 0.4848856955194765, and the acceleration is -0.10256974427640982
# the velocity is 0.49309886492898514, and the acceleration is -0.27964654977999875
# the velocity is 0.4674814091922604, and the acceleration is -0.19853570935628256
# the velocity is 0.45704066450168856, and the acceleration is -0.16939757817716436
# the velocity is 0.43953192085671444, and the acceleration is -0.05287449669453917
# the velocity is 0.43480880314763304, and the acceleration is -0.20153389369142974
# the velocity is 0.4291594577022333, and the acceleration is -0.12502143687872064
# the velocity is 0.41316805310994753, and the acceleration is -0.06287586691562251
# the velocity is 0.41395979183660003, and the acceleration is -0.2320063493845037
# the velocity is 0.4016333347844651, and the acceleration is -0.18342302035223046
# the velocity is 0.38661975838460005, and the acceleration is -0.10678807718963204
# the velocity is 0.3760918341562738, and the acceleration is -0.17224771855470855
# the velocity is 0.36849054631956873, and the acceleration is -0.2753135242208404
# the velocity is 0.3412581701930436, and the acceleration is -0.19050682196096283
# the velocity is 0.3335203627451942, and the acceleration is -0.06585299395545832
# the velocity is 0.3373909016789462, and the acceleration is -0.07782319434765439
# the velocity is 0.33188030525949724, and the acceleration is -0.25666232513027204
# the velocity is 0.3065855603283969, and the acceleration is -0.02456140006445236
# the velocity is 0.30570625880588, and the acceleration is -0.0640871089320871
# the velocity is 0.3039105767620973, and the acceleration is -0.11320760316906223
# the velocity is 0.2978967931276974, and the acceleration is -0.1274802477093331
# the velocity is 0.28936852566269466, and the acceleration is -0.07318411151280228
# the velocity is 0.2863661639908664, and the acceleration is -0.16836999513483228
# the velocity is 0.2703685905513345, and the acceleration is -0.2335230141108481
# the velocity is 0.26016794290127754, and the acceleration is -0.1000698099442981
# the velocity is 0.2447393211432848, and the acceleration is -0.08937889557465208
# the velocity is 0.23006900619757711, and the acceleration is -0.2397440627774974
# the velocity is 0.22414129748874292, and the acceleration is -0.10033882803696288
# the velocity is 0.21894303154361336, and the acceleration is -0.24983242497233132
# the velocity is 0.19405735852706454, and the acceleration is -0.2073549310099529
# the velocity is 0.19038598897548326, and the acceleration is -0.13415628353844217
# the velocity is 0.18149509978904435, and the acceleration is -0.14933617443589348
# the velocity is 0.1684143720587701, and the acceleration is -0.16826663627310728
# the velocity is 0.15955086792131348, and the acceleration is -0.1327183106089695
# the velocity is 0.15073193443504723, and the acceleration is -0.25113265148582686
# the velocity is 0.1305404294272682, and the acceleration is -0.19589752519158693
# the velocity is 0.11459391192730509, and the acceleration is -0.09055073424663207
# the velocity is 0.11137334427339811, and the acceleration is -0.1956534998301351
# the velocity is 0.08719672622286477, and the acceleration is -0.07200935021524515
# the velocity is 0.09676500286512225, and the acceleration is -0.11990426431502975
# the velocity is 0.08286790552326107, and the acceleration is -0.07114577865083205
# the velocity is 0.087937583462726, and the acceleration is -0.012612269449888932
# the velocity is 0.07515232568337075, and the acceleration is -0.15477217764707224
# the velocity is 0.07695111988919939, and the acceleration is -0.16586345031620142
# the velocity is 0.06059797760069957, and the acceleration is -0.1832211724291072
# the velocity is 0.05014583114859261, and the acceleration is -0.20607312778549333
# the velocity is 0.032937706907758886, and the acceleration is -0.14287213291568585
# the velocity is 0.021064864315584627, and the acceleration is -0.1851362316167436
# the velocity is 0.0041908195513823444, and the acceleration is -0.1285154957253951
# the velocity is 0.015703467858115307, and the acceleration is -0.060423785738616904
# 2267
# length of filtered data: 2259

# %% [markdown]
# ## Coefficient Estimation via Linear Regression

# %%
'''
Lookup the sklearn LinearRegression documenation if need be.
Alternatively you may reference housing_demo.py

1. Instantiate a LinearRegression Model.
2. Fit the model with all inputs and all outputs.
3. Assign 'fit_score' to the sklearn score on the inputs and outputs.
4. Extract the learned coefficients and intercept (see coef_ and intercept_ attributes)
'''

model = LinearRegression()
model.fit(all_inps, all_outs)
fit_score = model.score(all_inps, all_outs)
coef, intercept = model.coef_, model.intercept_

print(f"Model Fit {fit_score}")
print(f"Model Predictions: ")


'''
Fill in the blanks in the next 4 lines with
references to the 4 learned coefficients

Remember the linear model is as follows:
accel = c_1 * accel_amt + c_2* brake_amt + c_3 * v + c_4

c_1: accelerator_weight
c_2: brake_weight
c_3: -friction_constant
c_4: rolling_bias
'''
print(f"Accelerator Weight: {coef[0]}")
print(f"Brake Weight: {coef[1]}")
print(f"Friction Constant: {-coef[2]}")
print(f"Rolling Bias: {intercept}")
print("___________________________________________")

plt.clf()
plt.title("Model Predictions on all Data")
plt.xlabel("Time")
plt.ylabel("Acceleration")
plt.scatter(all_times, all_outs, color = 'b')
plt.scatter(all_times, model.predict(all_inps), color = 'r')
plt.show()
# Out:
# Model Fit 0.9652377377804846
# Model Predictions:
# Accelerator Weight: 0.1016901449835141
# Brake Weight: -0.23292502999591808
# Friction Constant: 0.11446857556122281
# Rolling Bias: 0.010729615827406211
# ___________________________________________

# %%
'''
You may use this function as is to evaluate the accuracy of
the model coefficients you have discovered.
'''
def evaluate(preds, targets, tol = 0.02):
    correct = 0
    errors = []

    for i, (prediction, target) in enumerate(zip(preds, targets)):
        print(f"EVALUATING {i + 1}/{len(all_inps)}", end = "\r")

        if (abs(prediction - target) < tol):
            correct += 1
        errors.append(prediction - target)

    print(f"WITHIN {tol} {correct}/{len(targets)} times")
    print(f"MEDIAN ERROR {np.median(np.abs(errors)):.4f}")

    plt.title("Error Distribution")
    plt.hist(errors, bins = 200, range = (-0.15, 0.15))
    plt.show()

# %%
evaluate(preds = model.predict(all_inps), targets = all_outs)
# Out:
# WITHIN 0.02 2261/2267 times
# MEDIAN ERROR 0.0007

# %%
'''
Repeat the previous process but now using the filtered
input and outputs only.
'''

model = LinearRegression()
model.fit(filt_inps, filt_outs)
fit_score = model.score(filt_inps, filt_outs)
coef, intercepts = model.coef_, model.intercept_

print(f"Model Fit {fit_score}")


'''
Fill in the blanks as in the previous section
'''
print(f"Accelerator Weight: {coef[0]}")
print(f"Brake Weight: {coef[1]}")
print(f"Friction Constant: {-coef[2]}")
print(f"Rolling Bias: {intercept}")
print("___________________________________________")


plt.clf()
plt.title("Filtered Data")
plt.scatter(filt_times, filt_outs, color = 'b')
plt.xlabel("Time")
plt.ylabel("Acceleration")
plt.show()

plt.clf()
plt.title("Model Predictions on Filtered Data")
plt.xlabel("Time")
plt.ylabel("Acceleration")
plt.scatter(filt_times, filt_outs, color = 'b')
plt.scatter(filt_times, model.predict(filt_inps), color = 'r')
plt.show()
# Out:
# Model Fit 0.9794934074636339
# Accelerator Weight: 0.10093329691813216
# Brake Weight: -0.23994890202881022
# Friction Constant: 0.11258267129345026
# Rolling Bias: 0.010729615827406211
# ___________________________________________

# %%
evaluate(preds = model.predict(filt_inps), targets = filt_outs)
# Out:
# WITHIN 0.02 2256/2259 times
# MEDIAN ERROR 0.0005

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Before you can evaluate our learned coefficients you will have to complete the controller_model.py file.  We will use the controller_model file to mimic the actual controller.
#
# 1. Around line 41 replace the 'None' placeholders with your learned coefficients.
# 2. Around line 115 follow the instructional comments to compute acceleration as a function of the pedal inputs.
# 3. Around line 163 follow the instructional comments to update position and velocity, assuming constant acceleration over the dt length time interval.
#
# Once you complete these steps you should be able to run the simulator in sysID_test mode (command below).
#
# python simulator.py --mode sysID_test
#
# Once you are able to successfully run this, drive around for a bit.  Just as we provide inputs to the actual controller Car_Interface, we will provide controls to the controller_model Car_Interface.  We consider the average discrepancy between the model velocity and the actual velocity over the last 100 time steps as the model error.
# In other words they are going to look at the last 100 time steps and take the average difference between the model velocity and the actualy velocity.
#
# You will notice your average error being displayed in your terminal window (after an preliminary period).  You will be checked off if the maximum average error does not exceed the threshold of 0.75% (an exception will be raised if it does). (NOTE: just noise will result in a perfect model having an error of ~0.4%)
